# %%
# !pip install nltk
import nltk
nltk.download('punkt')
import requests
from  sklearn.feature_extraction.text import TfidfVectorizer
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics.pairwise import cosine_similarity
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
import numpy as np
import urllib
import pandas as pd
from collections import Counter
import spacy
import numpy as np
import pandas as pd 


list_of_books = {    
    'Silaczka': 'https://wolnelektury.pl/media/book/txt/silaczka.txt',
    'Syzyfowe prace': 'https://wolnelektury.pl/media/book/txt/syzyfowe-prace.txt',
    'Przedwiosnie': 'https://wolnelektury.pl/media/book/txt/przedwiosnie.txt',
    'Wierna rzeka': 'https://wolnelektury.pl/media/book/txt/wierna-rzeka.txt'
}

stopwordy = (urllib.request.urlopen('https://raw.githubusercontent.com/bieli/stopwords/master/polish.stopwords.txt').read().decode('utf8')).split('\n')
nlp = spacy.load("pl_core_news_md")
tokens = list(filter(lambda x: x.text.isalpha() and x.lemma_ not in stopwordy and len(x.text) > 1, nlp(urllib.request.urlopen(
    'https://wolnelektury.pl/media/book/txt/silaczka.txt').read().decode('utf8'))))
tokenlist = [ksiazka.lemma_.lower() for ksiazka in tokens]
#tylko 15 elementow ze wzgledu na duzy plik
czestosc = Counter(tokenlist)
czestosc
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting nltk
#   Downloading nltk-3.8.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 9.9 MB/s eta 0:00:00ta 0:00:01
# Requirement already satisfied: tqdm in /home/sylwester.mikolajczuk/.sage/local/lib/python3.10/site-packages (from nltk) (4.64.1)
# Requirement already satisfied: click in /home/sylwester.mikolajczuk/.sage/local/lib/python3.10/site-packages (from nltk) (8.1.3)
# Requirement already satisfied: joblib in /home/sylwester.mikolajczuk/.sage/local/lib/python3.10/site-packages (from nltk) (1.2.0)
# Collecting regex>=2021.8.3
#   Downloading regex-2022.10.31-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (770 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 770.5/770.5 kB 39.8 MB/s eta 0:00:00
# Installing collected packages: regex, nltk
#   WARNING: The script nltk is installed in '/home/sylwester.mikolajczuk/.sage/local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# Successfully installed nltk-3.8.1 regex-2022.10.31
# [nltk_data] Downloading package punkt to
# [nltk_data]     /home/sylwester.mikolajczuk/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Counter({'doktor': 66, 'mieć': 30, 'siebie': 22, 'czas': 19, 'zacząć': 19, 'koń': 17, 'chwila': 16, 'oko': 16, 'móc': 15, 'ręka': 15, 'chory': 13, 'myśl': 12, 'głowa': 12, 'paweł': 11, 'obarecki': 11, 'godzina': 11, 'okno': 11, 'raz': 11, 'wolny': 11, 'chłop': 11, 'las': 10, 'człowiek': 9, 'mówić': 9, 'serce': 9, 'niby': 9, 'swój': 9, 'dać': 9, 'wiedzieć': 9, 'śnieg': 9, 'książka': 9, 'dom': 8, 'obrzydłówka': 8, 'stać': 8, 'wiatr': 8, 'wyraz': 8, 'myśleć': 8, 'wielki': 8, 'nauczycielka': 8, 'sanie': 8, 'izba': 8, 'aptekarz': 7, 'drzwi': 7, 'choćby': 7, 'wieś': 7, 'droga': 7, 'iść': 7, 'usta': 7, 'nagle': 7, 'noga': 7, 'sołtys': 7, 'bok': 7, 'panienka': 7, 'twarz': 7, 'powrócić': 6, 'czuć': 6, 'pisać': 6, 'leżeć': 6, 'ziemia': 6, 'pole': 6, 'rok': 6, 'zaraz': 6, 'młody': 6, 'podobny': 6, 'duch': 6, 'prawda': 6, 'zdawać': 6, 'mały': 6, 'potem': 6, 'trzy': 6, 'głos': 6, 'łóżko': 6, 'panna': 6, 'lektura': 6, 'ciąg': 5, 'gospodynia': 5, 'zaś': 5, 'metafizyka': 5, 'stan': 5, 'bezwiednie': 5, 'smutek': 5, 'dusza': 5, 'ostatni': 5, 'ból': 5, 'ksiądz': 5, 'jechać': 5, 'miejsce': 5, 'noc': 5, 'wieczór': 5, 'pewien': 5, 'piękny': 5, 'chcieć': 5, 'wizyta': 5, 'siła': 5, 'wkrótce': 5, 'padać': 5, 'włos': 5, 'zawołać': 5, 'pokój': 5, 'szeptać': 5, 'pojechać': 5, 'spotykać': 5, 'pleban': 4, 'stolik': 4, 'stół': 4, 'życie': 4, 'umierać': 4, 'mózg': 4, 'energia': 4, 'papieros': 4, 'pomoc